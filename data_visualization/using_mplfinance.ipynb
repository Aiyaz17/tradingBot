# %%
# !pip install mplfinance
import pandas as pd
import mplfinance as mpf
import datetime as dt

# %%
df = pd.read_csv("../data/TataSteel.csv",index_col=0,parse_dates=True)
df.index.name = 'Date'
df.shape
df.head(3)
# Out:
#                              open    high     low   close     volume
# Date
# 2021-07-01 09:15:00+05:30  117.19  117.19  115.65  116.31  4809510.0
# 2021-07-01 09:20:00+05:30  116.35  117.20  116.26  116.97  2844120.0
# 2021-07-01 09:25:00+05:30  116.93  117.16  116.70  117.03  1459550.0

# %%
df1 = df.loc[(df.index>'2022-07-29') & (df.index<'2022-07-30')]
df1.head()
mpf.plot(df1,type='candle')
# mpf.plot(df1,type='candle',mav=20)
# mpf.plot(df1,type='candle',mav=(5,20))
# mpf.plot(df1,type='candle',volume=True)
# mpf.plot(df1,type='ohlc')
# mpf.plot(df,type='line')
