# %%
# !pip install mplfinance
import pandas as pd
import mplfinance as mpf
import datetime as dt

# %%
df = pd.read_csv("../data/TataMotors.csv",index_col=0,parse_dates=True)
df.index.name = 'Date'
df.shape
df.head(3)
# Out:
#                              open    high    low  close     volume
# Date
# 2021-07-01 09:15:00+05:30  341.50  343.20  341.2  342.1  1814940.0
# 2021-07-01 09:20:00+05:30  341.95  344.95  341.6  344.4  1647938.0
# 2021-07-01 09:25:00+05:30  344.30  345.20  343.6  343.9  1009616.0

# %%
df1 = df.loc[(df.index>'2022-07-29') & (df.index<'2022-07-30')]
df1.head()
# Out:
#                              open    high     low   close    volume
# Date
# 2022-07-29 09:15:00+05:30  445.15  448.65  445.15  445.65  882185.0
# 2022-07-29 09:20:00+05:30  445.75  450.30  445.50  449.55  887033.0
# 2022-07-29 09:25:00+05:30  449.50  451.50  449.05  449.30  663953.0
# 2022-07-29 09:30:00+05:30  448.80  449.40  448.40  449.00  387947.0
# 2022-07-29 09:35:00+05:30  449.15  450.55  448.70  450.50  423345.0

# %%
mpf.plot(df1,type='candle')

# %%
mpf.plot(df1,type='candle',mav=20)

# %%
mpf.plot(df1,type='candle',mav=(5,20))

# %%
mpf.plot(df1,type='candle',volume=True)

# %%
mpf.plot(df1,type='ohlc')

# %%
mpf.plot(df,type='line')
